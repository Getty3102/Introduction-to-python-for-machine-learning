# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/home/user/learning/hamoye/FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding = 'latin-1')
data.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
tuppy = (2,3,4,5)
tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/user/learning/hamoye/tag_along_project.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/user/learning/hamoye/tag_along_project.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> tuppy = (2,3,4,5)
# ----> <a href='vscode-notebook-cell:/home/user/learning/hamoye/tag_along_project.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
data.groupby('Item').sum()
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
data.groupby('Area')['Y2017'].sum().sort_values(ascending = True)
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
missing = data['Y2014'].isna().sum()
per_missing = missing/len(data)*100
print(missing)
print(per_missing)
# Out:
# 1589
# 2.6073544131401474

# %%
cols = ['Y2014','Y2015','Y2016','Y2017','Y2018']

stock = []

for col in cols:
    stock_var = data.groupby('Element')[col].sum()
    stock.append(stock_var)
pd.DataFrame(stock)
# Out:
# Element  Domestic supply quantity  Export Quantity  \
# Y2014                  1996716.35        150020.64
# Y2015                  2021493.55        157614.47
# Y2016                  2044842.70        151920.46
# Y2017                  2088198.10        182338.80
# Y2018                  2161192.10        181594.80
#
# Element  Fat supply quantity (g/capita/day)       Feed        Food  \
# Y2014                              10225.56  216927.89  1212332.49
# Y2015                              10235.74  225050.22  1232361.10
# Y2016                              10102.77  228958.65  1247022.17
# Y2017                              10253.84  223705.68  1258888.28
# Y2018                              10258.69  233489.68  1303841.28
#
# Element  Food supply (kcal/capita/day)  Food supply quantity (kg/capita/yr)  \
# Y2014                         454257.0                             49650.63
# Y2015                         453383.0                             49345.13
# ...

# %%
cols = ['Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']

stock = []

for col in cols:
    stock_var = data.groupby(['Area', 'Element'])[col].sum()
    stock.append(stock_var)

stock_df = pd.concat(stock, axis=1).reset_index()
stock_df.columns = ['Area', 'Element'] + cols

madagascar_stock = stock_df[stock_df['Area'] == 'Madagascar']

madagascar_stock
# Out:
#            Area                                 Element     Y2014     Y2015  \
# 411  Madagascar                Domestic supply quantity  31578.76  31214.98
# 412  Madagascar                         Export Quantity    425.48    494.75
# 413  Madagascar      Fat supply quantity (g/capita/day)     88.72     91.85
# 414  Madagascar                                    Feed   2178.76   2070.22
# 415  Madagascar                                    Food  21405.42  21120.65
# 416  Madagascar           Food supply (kcal/capita/day)   7945.00   7685.00
# 417  Madagascar     Food supply quantity (kg/capita/yr)    907.59    871.59
# 418  Madagascar                         Import Quantity   2010.71   1721.80
# 419  Madagascar                                  Losses   2252.00   2176.00
# 420  Madagascar                   Other uses (non-food)   4348.58   3957.12
# 421  Madagascar                              Processing   1262.00   1803.00
# ...

# %%
len(data['Area'].unique())
# Out:
# 49

# %%
data.groupby('Area')['Y2015'].sum().sort_values(ascending = True).index[7]
# Out:
# 'Guinea-Bissau'
